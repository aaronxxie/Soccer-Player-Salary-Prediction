# %% [markdown]
# # Soccoer Player Salary Prediction 2023
# #### Python, Machine Learning
# Aaron Xie
# ___

# %% [markdown]
# # Table of Contents
#
# ___

# %% [markdown]
# <a id="problem"></a>
# # 1. The Problem

# %% [markdown]
# One of the biggest events around the world in 2022 is that Lionel Messi and argentina national football team won the World Cup. This winning solidfies the fact that Messi is one of the greatest soccer players of all time. This fact also raises the main questions:
# * Should Messi have the highest salary because of his glory honors and rich experience?
# * Messi is already 35; can his age and other factors drag down his salary?
# * When football manager hire a soccer player, how can they determine the player's salary?

# %% [markdown]
# ### 1.1. Goals
# * Conduct EDA on this data set.
# * Use machine learning algorithms to predict a player's salary.
# * Find the most accurate machine learning algorithm in this case.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from sklearn.model_selection import train_test_split

# %% [markdown]
# <a id="preparation"></a>
# # 2. Data Preparation

# %% [markdown]
# ### Import the Data Set
# Since it is either hard or impossible to get the real world data of soccer players. This project uses a fictional data set from the game FIFA 2023. The data set was published in [Kaggle](https://www.kaggle.com/datasets/cashncarry/fifa-23-complete-player-dataset) by ALEX.

# %%
df = pd.read_csv(r"C:\Users\zong0\OneDrive\Documents\Data_Science\My_Projects\GitHub\Soccer-Player-Salary-Prediction\players_fifa23.csv")
train_df, test_df = train_test_split(df, test_size = 0.2)

# %% [markdown]
# ### Describe the Data

# %%
train_df.shape
# Out:
# (14831, 90)

# %% [markdown]
# This data set has 89 features! Checking columns.

# %%
print(train_df.columns.values)
# Out:
# ['ID' 'Name' 'FullName' 'Age' 'Height' 'Weight' 'PhotoUrl' 'Nationality'
#  'Overall' 'Potential' 'Growth' 'TotalStats' 'BaseStats' 'Positions'
#  'BestPosition' 'Club' 'ValueEUR' 'WageEUR' 'ReleaseClause' 'ClubPosition'
#  'ContractUntil' 'ClubNumber' 'ClubJoined' 'OnLoad' 'NationalTeam'
#  'NationalPosition' 'NationalNumber' 'PreferredFoot' 'IntReputation'
#  'WeakFoot' 'SkillMoves' 'AttackingWorkRate' 'DefensiveWorkRate'
#  'PaceTotal' 'ShootingTotal' 'PassingTotal' 'DribblingTotal'
#  'DefendingTotal' 'PhysicalityTotal' 'Crossing' 'Finishing'
#  'HeadingAccuracy' 'ShortPassing' 'Volleys' 'Dribbling' 'Curve'
#  'FKAccuracy' 'LongPassing' 'BallControl' 'Acceleration' 'SprintSpeed'
#  'Agility' 'Reactions' 'Balance' 'ShotPower' 'Jumping' 'Stamina'
#  'Strength' 'LongShots' 'Aggression' 'Interceptions' 'Positioning'
#  'Vision' 'Penalties' 'Composure' 'Marking' 'StandingTackle'
#  'SlidingTackle' 'GKDiving' 'GKHandling' 'GKKicking' 'GKPositioning'
#  'GKReflexes' 'STRating' 'LWRating' 'LFRating' 'CFRating' 'RFRating'
#  'RWRating' 'CAMRating' 'LMRating' 'CMRating' 'RMRating' 'LWBRating'
#  'CDMRating' 'RWBRating' 'LBRating' 'CBRating' 'RBRating' 'GKRating']

# %%
pd.set_option('display.max_columns', None) # default is 20
train_df.head()
# Out:
#            ID           Name                   FullName  Age  Height  Weight  \
# 14098  205315      E. Murray                Euan Murray   28     190      79
# 16862  267472       O. Smyth                Oisin Smyth   22     181      72
# 10077  266687  Tiago Ribeiro  Tiago Miguel Hora Ribeiro   20     185      73
# 11798  231145   J. Pritchard              Joe Pritchard   25     174      66
# 13859  266663      J. Romero              Julián Romero   18     178      73
#
#                                                PhotoUrl       Nationality  \
# 14098  https://cdn.sofifa.net/players/205/315/23_60.png          Scotland
# 16862  https://cdn.sofifa.net/players/267/472/23_60.png  Northern Ireland
# 10077  https://cdn.sofifa.net/players/266/687/23_60.png          Portugal
# 11798  https://cdn.sofifa.net/players/231/145/23_60.png           England
# 13859  https://cdn.sofifa.net/players/266/663/23_60.png         Argentina
#
#        Overall  Potential  Growth  TotalStats  BaseStats   Positions  \
# 14098       61         61       0        1458        311          CB
# 16862       57         66       9        1565        337      CAM,CM
# 10077       65         81      16        1826        380         CDM
# 11798       64         65       1        1775        379  RM,RWB,LWB
# 13859       62         74      12        1653        350          ST
#
#       BestPosition                         Club  ValueEUR  WageEUR  \
# 14098           CB            Hartlepool United    275000     2000
# 16862          CAM                Oxford United    375000     2000
# 10077           CM                  Valencia CF   1800000     7000
# 11798           RM           Accrington Stanley    700000     2000
# 13859          CAM  Club Atlético Independiente    925000     1000
#
#        ReleaseClause ClubPosition  ContractUntil  ClubNumber  ClubJoined  \
# 14098         481000          SUB         2024.0         5.0        2022
# 16862         731000          SUB         2025.0        25.0        2022
# 10077              0          RES         2023.0        41.0        2020
# 11798        1300000          SUB         2023.0        10.0        2019
# 13859        1600000          RES         2022.0        44.0        2021
#
#        OnLoad NationalTeam NationalPosition  NationalNumber PreferredFoot  \
# 14098   False  Not in team              NaN             NaN         Right
# 16862   False  Not in team              NaN             NaN         Right
# 10077    True  Not in team              NaN             NaN          Left
# 11798   False  Not in team              NaN             NaN         Right
# 13859   False  Not in team              NaN             NaN         Right
#
#        IntReputation  WeakFoot  SkillMoves AttackingWorkRate  \
# 14098              1         2           2            Medium
# 16862              1         3           3            Medium
# 10077              1         2           2            Medium
# 11798              1         3           3              High
# 13859              1         3           3            Medium
#
#       DefensiveWorkRate  PaceTotal  ShootingTotal  PassingTotal  \
# 14098            Medium         53             35            46
# 16862            Medium         66             46            57
# 10077            Medium         63             63            69
# 11798              High         73             61            62
# 13859            Medium         76             61            56
#
#        DribblingTotal  DefendingTotal  PhysicalityTotal  Crossing  Finishing  \
# 14098              46              59                72        38         33
# 16862              60              47                61        49         46
# 10077              61              62                62        68         53
# 11798              66              57                60        62         60
# 13859              66              34                57        49         61
#
#        HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  \
# 14098               61            53       27         42     28          29
# 16862               42            61       43         59     42          49
# 10077               56            69       54         59     76          77
# 11798               52            63       53         65     62          60
# 13859               52            59       59         63     57          50
#
#        LongPassing  BallControl  Acceleration  SprintSpeed  Agility  \
# 14098           48           47            52           54       44
# 16862           60           57            63           68       72
# 10077           67           65            64           62       63
# 11798           57           63            75           72       78
# 13859           53           62            82           71       89
#
#        Reactions  Balance  ShotPower  Jumping  Stamina  Strength  LongShots  \
# 14098         50       73         49       74       69        76         24
# 16862         52       73         46       55       60        65         48
# 10077         59       58         77       56       56        65         74
# 11798         59       81         63       54       64        58         66
# 13859         63       81         64       49       54        56         58
#
#        Aggression  Interceptions  Positioning  Vision  Penalties  Composure  \
# 14098          66             58           31      48         56         53
# 16862          52             45           46      61         50         56
# 10077          63             63           53      66         64         63
# 11798          59             57           57      64         54         64
# 13859          65             33           65      61         49         65
#
#        Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 14098       59              60             60        12           8
# 16862       48              50             42        13          13
# 10077       61              65             63         9           7
# 11798       58              59             56         8           6
# 13859       30              34             32        12           9
#
#        GKKicking  GKPositioning  GKReflexes  STRating  LWRating  LFRating  \
# 14098         11             10           8        47        43        44
# 16862         14             13           8        54        56        55
# 10077         15              6          13        63        62        62
# 11798          9             10          11        63        64        63
# 13859          7             13          11        64        63        63
#
#        CFRating  RFRating  RWRating  CAMRating  LMRating  CMRating  RMRating  \
# 14098        44        44        43         46        48        51        48
# 16862        55        55        56         59        59        58        59
# 10077        62        62        62         65        64        66        64
# 11798        63        63        64         65        65        63        65
# 13859        63        63        63         65        64        59        64
#
#        LWBRating  CDMRating  RWBRating  LBRating  CBRating  RBRating  GKRating
# 14098         56         58         56        57        61        57        16
# 16862         55         56         55        54        53        54        18
# 10077         65         66         65        65        65        65        17
# 11798         64         62         64        63        60        63        16
# 13859         52         50         52        50        46        50        19

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14831 entries, 14098 to 14864
# Data columns (total 90 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 14831 non-null  int64
#  1   Name               14831 non-null  object
#  2   FullName           14831 non-null  object
#  3   Age                14831 non-null  int64
#  4   Height             14831 non-null  int64
#  5   Weight             14831 non-null  int64
#  6   PhotoUrl           14831 non-null  object
#  7   Nationality        14831 non-null  object
#  8   Overall            14831 non-null  int64
#  9   Potential          14831 non-null  int64
#  10  Growth             14831 non-null  int64
#  11  TotalStats         14831 non-null  int64
#  12  BaseStats          14831 non-null  int64
#  13  Positions          14831 non-null  object
#  14  BestPosition       14831 non-null  object
#  15  Club               14831 non-null  object
#  16  ValueEUR           14831 non-null  int64
#  17  WageEUR            14831 non-null  int64
#  18  ReleaseClause      14831 non-null  int64
#  19  ClubPosition       14761 non-null  object
#  20  ContractUntil      14761 non-null  float64
#  21  ClubNumber         14761 non-null  float64
#  22  ClubJoined         14831 non-null  int64
#  23  OnLoad             14831 non-null  bool
#  24  NationalTeam       14831 non-null  object
#  25  NationalPosition   644 non-null    object
#  26  NationalNumber     644 non-null    float64
#  27  PreferredFoot      14831 non-null  object
#  28  IntReputation      14831 non-null  int64
#  29  WeakFoot           14831 non-null  int64
#  30  SkillMoves         14831 non-null  int64
#  31  AttackingWorkRate  14831 non-null  object
#  32  DefensiveWorkRate  14831 non-null  object
#  33  PaceTotal          14831 non-null  int64
#  34  ShootingTotal      14831 non-null  int64
#  35  PassingTotal       14831 non-null  int64
#  36  DribblingTotal     14831 non-null  int64
#  37  DefendingTotal     14831 non-null  int64
#  38  PhysicalityTotal   14831 non-null  int64
#  39  Crossing           14831 non-null  int64
#  40  Finishing          14831 non-null  int64
#  41  HeadingAccuracy    14831 non-null  int64
#  42  ShortPassing       14831 non-null  int64
#  43  Volleys            14831 non-null  int64
#  44  Dribbling          14831 non-null  int64
#  45  Curve              14831 non-null  int64
#  46  FKAccuracy         14831 non-null  int64
#  47  LongPassing        14831 non-null  int64
#  48  BallControl        14831 non-null  int64
#  49  Acceleration       14831 non-null  int64
#  50  SprintSpeed        14831 non-null  int64
#  51  Agility            14831 non-null  int64
#  52  Reactions          14831 non-null  int64
#  53  Balance            14831 non-null  int64
#  54  ShotPower          14831 non-null  int64
#  55  Jumping            14831 non-null  int64
#  56  Stamina            14831 non-null  int64
#  57  Strength           14831 non-null  int64
#  58  LongShots          14831 non-null  int64
#  59  Aggression         14831 non-null  int64
#  60  Interceptions      14831 non-null  int64
#  61  Positioning        14831 non-null  int64
#  62  Vision             14831 non-null  int64
#  63  Penalties          14831 non-null  int64
#  64  Composure          14831 non-null  int64
#  65  Marking            14831 non-null  int64
#  66  StandingTackle     14831 non-null  int64
#  67  SlidingTackle      14831 non-null  int64
#  68  GKDiving           14831 non-null  int64
#  69  GKHandling         14831 non-null  int64
#  70  GKKicking          14831 non-null  int64
#  71  GKPositioning      14831 non-null  int64
#  72  GKReflexes         14831 non-null  int64
#  73  STRating           14831 non-null  int64
#  74  LWRating           14831 non-null  int64
#  75  LFRating           14831 non-null  int64
#  76  CFRating           14831 non-null  int64
#  77  RFRating           14831 non-null  int64
#  78  RWRating           14831 non-null  int64
#  79  CAMRating          14831 non-null  int64
#  80  LMRating           14831 non-null  int64
#  81  CMRating           14831 non-null  int64
#  82  RMRating           14831 non-null  int64
#  83  LWBRating          14831 non-null  int64
#  84  CDMRating          14831 non-null  int64
#  85  RWBRating          14831 non-null  int64
#  86  LBRating           14831 non-null  int64
#  87  CBRating           14831 non-null  int64
#  88  RBRating           14831 non-null  int64
#  89  GKRating           14831 non-null  int64
# dtypes: bool(1), float64(3), int64(73), object(13)
# memory usage: 10.2+ MB
